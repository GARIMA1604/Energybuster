# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from scipy import stats
import re
const map = document.getElementById('map');
const imageContainer = document.getElementById('image-container');

map.addEventListener('click', () => {
    imageContainer.style.display = 'block'; // Show the image container
});

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Specify the Excel file path (replace with yours)
file_path = "yes good like this give me for all the states.xlsx"

# Read the first sheet (or specify sheet name if different)
data = pd.read_excel(file_path, sheet_name=0)

# Select the two columns you want to visualize
col1 = data["State"]  # Replace with your actual column names
col2 = data["Avg. Daily Solar Radiation (kWh/m²)"]  # Replace with your actual column names

# Choose the type of visualization (replace 'bar' with 'line' or 'scatter' for different plots)
plt.figure(figsize=(14, 8))  # Adjust figure size as needed
plt.bar(col1, col2)  # Replace with your preferred chart type like 'plot' for line chart

# Customize the plot for better readability
plt.xlabel(col1.name)  # Use column name for label
plt.ylabel(col2.name)  # Use column name for label
plt.title("Avg. Daily Solar Radiation of States ")
plt.xticks(rotation=45, ha="right")  # Rotate long x-axis labels (optional)
plt.tight_layout()

# Display the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Specify the Excel file path (replace with yours)
file_path = "yes good like this give me for all the states.xlsx"

# Read the first sheet (or specify sheet name if different)
data = pd.read_excel(file_path, sheet_name=0)

# Select the columns you want to visualize
state = data["State"]  # Replace with actual column name for state
system_cost = data["---------------------------------------------------------------------------
TypeError                                 Traceback (most recent call last)
File c:\Users\91705\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axis.py:1769, in Axis.convert_units(self, x)
   1768 try:
-> 1769     ret = self.converter.convert(x, self.units, self)
   1770 except Exception as e:

File c:\Users\91705\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\category.py:57, in StrCategoryConverter.convert(value, unit, axis)
     56 # force an update so it also does type checking
---> 57 unit.update(values)
     58 return np.vectorize(unit._mapping.__getitem__, otypes=[float])(values)

File c:\Users\91705\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\category.py:216, in UnitData.update(self, data)
    214 for val in OrderedDict.fromkeys(data):
    215     # OrderedDict just iterates over unique values in data.
--> 216     _api.check_isinstance((str, bytes), value=val)
    217     if convertible:
    218         # this will only be called so long as convertible is True.

File c:\Users\91705\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\_api\__init__.py:91, in check_isinstance(types, **kwargs)
     90     names.append("None")
---> 91 raise TypeError(
     92     "{!r} must be an instance of {}, not a {}".format(
     93         k,
     94         ", ".join(names[:-1]) + " or " + names[-1]
     95         if len(names) > 1 else names[0],
     96         type_name(type(v))))

TypeError: 'value' must be an instance of str or bytes, not a float

The above exception was the direct cause of the following exception:

ConversionError                           Traceback (most recent call last)
File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\formatters.py:343, in BaseFormatter.__call__(self, obj)
    341     pass
    342 else:
--> 343     return printer(obj)
    344 # Finally look for special method names
    345 method = get_real_method(obj, self.print_method)

File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
    149     from matplotlib.backend_bases import FigureCanvasBase
    150     FigureCanvasBase(fig)
--> 152 fig.canvas.print_figure(bytes_io, **kw)
    153 data = bytes_io.getvalue()
    154 if fmt == 'svg':

File c:\Users\91705\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\backend_bases.py:2164, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
   2161     # we do this instead of `self.figure.draw_without_rendering`
   2162     # so that we can inject the orientation
   2163     with getattr(renderer, "_draw_disabled", nullcontext)():
-> 2164         self.figure.draw(renderer)
   2165 if bbox_inches:
   2166     if bbox_inches == "tight":

File c:\Users\91705\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
     93 @wraps(draw)
     94 def draw_wrapper(artist, renderer, *args, **kwargs):
---> 95     result = draw(artist, renderer, *args, **kwargs)
     96     if renderer._rasterizing:
     97         renderer.stop_rasterizing()

File c:\Users\91705\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
     69     if artist.get_agg_filter() is not None:
     70         renderer.start_filter()
---> 72     return draw(artist, renderer)
     73 finally:
     74     if artist.get_agg_filter() is not None:

File c:\Users\91705\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\figure.py:3154, in Figure.draw(self, renderer)
   3151         # ValueError can occur when resizing a window.
   3153 self.patch.draw(renderer)
-> 3154 mimage._draw_list_compositing_images(
   3155     renderer, self, artists, self.suppressComposite)
   3157 for sfig in self.subfigs:
   3158     sfig.draw(renderer)

File c:\Users\91705\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
    130 if not_composite or not has_images:
    131     for a in artists:
--> 132         a.draw(renderer)
    133 else:
    134     # Composite any adjacent images together
    135     image_group = []

File c:\Users\91705\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
     69     if artist.get_agg_filter() is not None:
     70         renderer.start_filter()
---> 72     return draw(artist, renderer)
     73 finally:
     74     if artist.get_agg_filter() is not None:

File c:\Users\91705\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axes\_base.py:3070, in _AxesBase.draw(self, renderer)
   3067 if artists_rasterized:
   3068     _draw_rasterized(self.figure, artists_rasterized, renderer)
-> 3070 mimage._draw_list_compositing_images(
   3071     renderer, self, artists, self.figure.suppressComposite)
   3073 renderer.close_group('axes')
   3074 self.stale = False

File c:\Users\91705\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
    130 if not_composite or not has_images:
    131     for a in artists:
--> 132         a.draw(renderer)
    133 else:
    134     # Composite any adjacent images together
    135     image_group = []

File c:\Users\91705\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
     69     if artist.get_agg_filter() is not None:
     70         renderer.start_filter()
---> 72     return draw(artist, renderer)
     73 finally:
     74     if artist.get_agg_filter() is not None:

File c:\Users\91705\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\collections.py:1005, in _CollectionWithSizes.draw(self, renderer)
   1002 @artist.allow_rasterization
   1003 def draw(self, renderer):
   1004     self.set_sizes(self._sizes, self.figure.dpi)
-> 1005     super().draw(renderer)

File c:\Users\91705\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
     69     if artist.get_agg_filter() is not None:
     70         renderer.start_filter()
---> 72     return draw(artist, renderer)
     73 finally:
     74     if artist.get_agg_filter() is not None:

File c:\Users\91705\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\collections.py:354, in Collection.draw(self, renderer)
    350 renderer.open_group(self.__class__.__name__, self.get_gid())
    352 self.update_scalarmappable()
--> 354 transform, offset_trf, offsets, paths = self._prepare_points()
    356 gc = renderer.new_gc()
    357 self._set_gc_clip(gc)

File c:\Users\91705\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\collections.py:326, in Collection._prepare_points(self)
    324     ys = self.convert_yunits(ys)
    325     paths.append(mpath.Path(np.column_stack([xs, ys]), path.codes))
--> 326 xs = self.convert_xunits(offsets[:, 0])
    327 ys = self.convert_yunits(offsets[:, 1])
    328 offsets = np.ma.column_stack([xs, ys])

File c:\Users\91705\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\artist.py:279, in Artist.convert_xunits(self, x)
    277 if ax is None or ax.xaxis is None:
    278     return x
--> 279 return ax.xaxis.convert_units(x)

File c:\Users\91705\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axis.py:1771, in Axis.convert_units(self, x)
   1769     ret = self.converter.convert(x, self.units, self)
   1770 except Exception as e:
-> 1771     raise munits.ConversionError('Failed to convert value(s) to axis '
   1772                                  f'units: {x!r}') from e
   1773 return ret

ConversionError: Failed to convert value(s) to axis units: masked_array(data=[--, --, --, --, --, --, --, --, --, --, --, --, --, --,
                   --, --, --, --, --, --, --, --, --, --, --, --, --, --],
             mask=[ True,  True,  True,  True,  True,  True,  True,  True,
                    True,  True,  True,  True,  True,  True,  True,  True,
                    True,  True,  True,  True,  True,  True,  True,  True,
                    True,  True,  True,  True],
       fill_value=1e+20,
            dtype=float64)"]  # Replace with actual column name

# Try converting potential numeric column
try:
    system_cost = pd.to_numeric(system_cost, errors='coerce')
except:
    print("Error converting 'System Cost' to numeric. Check data types.")

# Choose the columns for the scatter plot
x = state
y = system_cost

# Scatter plot (consider box plots for comparing distributions)
plt.figure(figsize=(14, 8))  # Adjust figure size as needed
plt.scatter(x, y)  # Plot state vs system cost

# Customize the plot for better readability
plt.xlabel("State")  # Label for x-axis
plt.ylabel("System Cost (kW)")  # Label for y-axis
plt.title("System Cost by State")
plt.xticks(rotation=45, ha="right")  # Rotate long state names (optional)
plt.grid(True)  # Optional grid lines for better readability

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\91705\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axis.py:1769, in Axis.convert_units(self, x)
#    1768 try:
# -> 1769     ret = self.converter.convert(x, self.units, self)
#    1770 except Exception as e:
#
# File c:\Users\91705\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\category.py:57, in StrCategoryConverter.convert(value, unit, axis)
#      56 # force an update so it also does type checking
# ---> 57 unit.update(values)
#      58 return np.vectorize(unit._mapping.__getitem__, otypes=[float])(values)
#
# File c:\Users\91705\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\category.py:216, in UnitData.update(self, data)
#     214 for val in OrderedDict.fromkeys(data):
#     215     # OrderedDict just iterates over unique values in data.
# ...

# %%
# Check for non-string values
non_strings = [val for val in data if not isinstance(val, str)]

# Option 1: Convert to strings (if applicable)
if all(isinstance(val, (int, float)) for val in non_strings):
  data = [str(val) for val in data]

# Option 2: Filter out unwanted values
data = [val for val in data if isinstance(val, str)]

# Now you can plot using the category axis
# ... (your plotting code)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Specify the Excel file path (replace with yours)
file_path = "yes good like this give me for all the states.xlsx"

# Read the first sheet (or specify sheet name if different)
data = pd.read_excel(file_path, sheet_name=0)

# Select the columns you want to visualize
state = data["State"]  # Replace with actual column name for state
system_cost = data["Payback Period (Years)"]  # Replace with actual column name

# Try converting potential numeric column
try:
    system_cost = pd.to_numeric(system_cost, errors='coerce')
except:
    print("Error converting 'System Cost' to numeric. Check data types.")

# Choose the columns for the scatter plot
x = state
y = system_cost

# Scatter plot (consider box plots for comparing distributions)
plt.figure(figsize=(14, 8))  # Adjust figure size as needed
plt.bar(x, y)  # Plot state vs system cost

# Customize the plot for better readability
plt.xlabel("State")  # Label for x-axis
plt.ylabel("Payback Period (Years)")  # Label for y-axis
plt.title("Payback Period (Years)by State")
plt.xticks(rotation=45, ha="right")  # Rotate long state names (optional)
plt.grid(True)  # Optional grid lines for better readability

# Display the plot
plt.tight_layout()
plt.show()
